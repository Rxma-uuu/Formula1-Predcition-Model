# %%
# Import all the required libraries
import fastf1
import pandas as pd

# Enable caching for faster data loading
fastf1.Cache.enable_cache('cache')

# %%
# Import the results_df dataset
results_df = pd.read_csv('model/DATA/f1_results_2024_2025.csv')

# %%
# Load driver data from an Excel file
drivers = pd.read_excel('model/DATA/f1_drivers_points_exp.xlsx')
drivers
# Out:
#            DriverName Abbreviation        TeamId  DriverExperience
# 0      Max Verstappen          VER      red_bull                11
# 1      Lewis Hamilton          HAM       ferrari                19
# 2     Charles Leclerc          LEC       ferrari                 8
# 3        Carlos Sainz          SAI      williams                11
# 4        Lando Norris          NOR       mclaren                 7
# 5      George Russell          RUS      mercedes                 7
# 6     Fernando Alonso          ALO  aston_martin                22
# 7       Oscar Piastri          PIA       mclaren                 3
# 8        Esteban Ocon          OCO          haas                 9
# 9        Pierre Gasly          GAS        alpine                 9
# 10       Lance Stroll          STR  aston_martin                 9
# 11       Yuki Tsunoda          TSU            rb                 5
# 12    Alexander Albon          ALB      williams                 6
# 13    Nico Hülkenberg          HUL        sauber                13
# 14     Oliver Bearman          BEA          haas                 1
# 15        Liam Lawson          LAW      red_bull                 2
# 16  Gabriel Bortoleto          BOR        sauber                 1
# 17     Kimi Antonelli          ANT      mercedes                 1
# 18        Jack Doohan          DOO        alpine                 1
# 19       Isack Hadjar          HAD            rb                 1

# %%
filtered_results = results_df[results_df["Abbreviation"].isin(drivers['Abbreviation'])]

# Group by driver and sum total points
total_points = filtered_results.groupby("Abbreviation")["Points"].sum().reset_index()

# Fill the missing rookie drivers with 0 points
all_drivers_df = pd.DataFrame({"Abbreviation": drivers["Abbreviation"]}) 
total_points = all_drivers_df.merge(total_points, on="Abbreviation", how="left").fillna(0) 

# Convert Points to absolute value interger for simpler point system
total_points["Points"] = total_points["Points"].astype(int)
total_points = total_points.sort_values(by="Points", ascending=False)

total_points
# Out:
#    Abbreviation  Points
# 0           VER     429
# 4           NOR     387
# 2           LEC     331
# 7           PIA     292
# 3           SAI     263
# 5           RUS     256
# 1           HAM     208
# 6           ALO      70
# 13          HUL      42
# 9           GAS      40
# 10          STR      34
# 8           OCO      33
# 11          TSU      29
# 12          ALB      28
# 17          ANT      20
# 14          BEA      11
# 15          LAW       4
# 16          BOR       0
# 18          DOO       0
# 19          HAD       0

# %%
drivers = total_points.merge(drivers, on="Abbreviation", how="left").fillna(0) 
drivers
# Out:
#    Abbreviation  Points         DriverName        TeamId  DriverExperience
# 0           VER     429     Max Verstappen      red_bull                11
# 1           NOR     387       Lando Norris       mclaren                 7
# 2           LEC     331    Charles Leclerc       ferrari                 8
# 3           PIA     292      Oscar Piastri       mclaren                 3
# 4           SAI     263       Carlos Sainz      williams                11
# 5           RUS     256     George Russell      mercedes                 7
# 6           HAM     208     Lewis Hamilton       ferrari                19
# 7           ALO      70    Fernando Alonso  aston_martin                22
# 8           HUL      42    Nico Hülkenberg        sauber                13
# 9           GAS      40       Pierre Gasly        alpine                 9
# 10          STR      34       Lance Stroll  aston_martin                 9
# 11          OCO      33       Esteban Ocon          haas                 9
# 12          TSU      29       Yuki Tsunoda            rb                 5
# 13          ALB      28    Alexander Albon      williams                 6
# 14          ANT      20     Kimi Antonelli      mercedes                 1
# 15          BEA      11     Oliver Bearman          haas                 1
# 16          LAW       4        Liam Lawson      red_bull                 2
# 17          BOR       0  Gabriel Bortoleto        sauber                 1
# 18          DOO       0        Jack Doohan        alpine                 1
# 19          HAD       0       Isack Hadjar            rb                 1

# %%
# Calculate average qualifying position for each driver
avg_quali_df = results_df.groupby('Abbreviation')['GridPosition'].mean().reset_index()
avg_quali_df.rename(columns={'GridPosition': 'AvgQualiPosition'}, inplace=True)

# %%
# Calculate average race position for each driver
avg_race_df = results_df.groupby('Abbreviation')['Position'].mean().reset_index()
avg_race_df.rename(columns={'Position': 'AvgRacePosition'}, inplace=True)

# %%
# Merge both dataframes
avg_pos_df = avg_quali_df.merge(avg_race_df, on='Abbreviation', how='outer')

# Merge the drivers DataFrame with avg_pos_df to include AvgQualiPosition and AvgRacePosition
drivers = drivers.merge(avg_pos_df, on='Abbreviation', how='left')

# Display updated drivers dataset
drivers
# Out:
#    Abbreviation  Points         DriverName        TeamId  DriverExperience  \
# 0           VER     429     Max Verstappen      red_bull                11
# 1           NOR     387       Lando Norris       mclaren                 7
# 2           LEC     331    Charles Leclerc       ferrari                 8
# 3           PIA     292      Oscar Piastri       mclaren                 3
# 4           SAI     263       Carlos Sainz      williams                11
# 5           RUS     256     George Russell      mercedes                 7
# 6           HAM     208     Lewis Hamilton       ferrari                19
# 7           ALO      70    Fernando Alonso  aston_martin                22
# 8           HUL      42    Nico Hülkenberg        sauber                13
# 9           GAS      40       Pierre Gasly        alpine                 9
# 10          STR      34       Lance Stroll  aston_martin                 9
# 11          OCO      33       Esteban Ocon          haas                 9
# 12          TSU      29       Yuki Tsunoda            rb                 5
# 13          ALB      28    Alexander Albon      williams                 6
# 14          ANT      20     Kimi Antonelli      mercedes                 1
# 15          BEA      11     Oliver Bearman          haas                 1
# 16          LAW       4        Liam Lawson      red_bull                 2
# 17          BOR       0  Gabriel Bortoleto        sauber                 1
# 18          DOO       0        Jack Doohan        alpine                 1
# 19          HAD       0       Isack Hadjar            rb                 1
#
#     AvgQualiPosition  AvgRacePosition
# 0           3.538462         3.576923
# 1           3.269231         4.076923
# 2           5.500000         5.192308
# 3           5.115385         5.115385
# 4           6.240000         6.360000
# 5           5.423077         6.461538
# 6           8.653846         7.538462
# 7           9.653846        10.692308
# 8          12.076923        11.576923
# 9          13.076923        13.076923
# 10         12.730769        12.923077
# 11         13.560000        13.320000
# 12         10.769231        13.230769
# 13         12.500000        13.884615
# 14         12.000000         5.000000
# 15         14.600000        10.200000
# 16         14.625000        13.500000
# 17         17.000000        15.000000
# 18         16.333333        15.666667
# 19          9.000000        15.500000

# %%
# Remove the 'TeamId' column from the drivers DataFrame as it's not needed
filtered_drivers_info = drivers.drop(['DriverExperience'], axis=1)
filtered_drivers_info
# Out:
#    Abbreviation  Points         DriverName        TeamId  AvgQualiPosition  \
# 0           VER     429     Max Verstappen      red_bull          3.538462
# 1           NOR     387       Lando Norris       mclaren          3.269231
# 2           LEC     331    Charles Leclerc       ferrari          5.500000
# 3           PIA     292      Oscar Piastri       mclaren          5.115385
# 4           SAI     263       Carlos Sainz      williams          6.240000
# 5           RUS     256     George Russell      mercedes          5.423077
# 6           HAM     208     Lewis Hamilton       ferrari          8.653846
# 7           ALO      70    Fernando Alonso  aston_martin          9.653846
# 8           HUL      42    Nico Hülkenberg        sauber         12.076923
# 9           GAS      40       Pierre Gasly        alpine         13.076923
# 10          STR      34       Lance Stroll  aston_martin         12.730769
# 11          OCO      33       Esteban Ocon          haas         13.560000
# 12          TSU      29       Yuki Tsunoda            rb         10.769231
# 13          ALB      28    Alexander Albon      williams         12.500000
# 14          ANT      20     Kimi Antonelli      mercedes         12.000000
# 15          BEA      11     Oliver Bearman          haas         14.600000
# 16          LAW       4        Liam Lawson      red_bull         14.625000
# 17          BOR       0  Gabriel Bortoleto        sauber         17.000000
# 18          DOO       0        Jack Doohan        alpine         16.333333
# 19          HAD       0       Isack Hadjar            rb          9.000000
#
#     AvgRacePosition
# 0          3.576923
# 1          4.076923
# 2          5.192308
# 3          5.115385
# 4          6.360000
# 5          6.461538
# 6          7.538462
# 7         10.692308
# 8         11.576923
# 9         13.076923
# 10        12.923077
# 11        13.320000
# 12        13.230769
# 13        13.884615
# 14         5.000000
# 15        10.200000
# 16        13.500000
# 17        15.000000
# 18        15.666667
# 19        15.500000

# %%
filtered_drivers_info.to_csv('model/DATA/filtered_drivers_info.csv')

# %%
# Select only relevant features from results_df for further processing
filtered_results_df = results_df[['Round', 'Abbreviation', 'GridPosition', 'Position']]
filtered_results_df
# Out:
#      Round Abbreviation  GridPosition  Position
# 0        1          VER           1.0       1.0
# 1        1          SAI           4.0       3.0
# 2        1          LEC           2.0       4.0
# 3        1          RUS           3.0       5.0
# 4        1          NOR           7.0       6.0
# ..     ...          ...           ...       ...
# 379      2          TSU           9.0      16.0
# 380      2          ALO          13.0      17.0
# 381      2          LEC           6.0      18.0
# 382      2          HAM           5.0      19.0
# 383      2          GAS          16.0      20.0
#
# [384 rows x 4 columns]

# %%
# Merge the filtered race results with driver information using 'Abbreviation' as the key
# This combines race performance with driver statistics and gives the final dataset to use for prediction
final_df = filtered_results_df.merge(filtered_drivers_info, on='Abbreviation', how='left')
final_df
# Out:
#      Round Abbreviation  GridPosition  Position  Points       DriverName  \
# 0        1          VER           1.0       1.0     429   Max Verstappen
# 1        1          SAI           4.0       3.0     263     Carlos Sainz
# 2        1          LEC           2.0       4.0     331  Charles Leclerc
# 3        1          RUS           3.0       5.0     256   George Russell
# 4        1          NOR           7.0       6.0     387     Lando Norris
# ..     ...          ...           ...       ...     ...              ...
# 379      2          TSU           9.0      16.0      29     Yuki Tsunoda
# 380      2          ALO          13.0      17.0      70  Fernando Alonso
# 381      2          LEC           6.0      18.0     331  Charles Leclerc
# 382      2          HAM           5.0      19.0     208   Lewis Hamilton
# 383      2          GAS          16.0      20.0      40     Pierre Gasly
#
#            TeamId  AvgQualiPosition  AvgRacePosition
# 0        red_bull          3.538462         3.576923
# 1        williams          6.240000         6.360000
# 2         ferrari          5.500000         5.192308
# 3        mercedes          5.423077         6.461538
# 4         mclaren          3.269231         4.076923
# ..            ...               ...              ...
# 379            rb         10.769231        13.230769
# 380  aston_martin          9.653846        10.692308
# 381       ferrari          5.500000         5.192308
# 382       ferrari          8.653846         7.538462
# 383        alpine         13.076923        13.076923
#
# [384 rows x 9 columns]

# %%
final_df["QualifyingScore"] = (final_df["AvgQualiPosition"] + final_df["GridPosition"]) / 2
final_df
# Out:
#      Round Abbreviation  GridPosition  Position  Points       DriverName  \
# 0        1          VER           1.0       1.0     429   Max Verstappen
# 1        1          SAI           4.0       3.0     263     Carlos Sainz
# 2        1          LEC           2.0       4.0     331  Charles Leclerc
# 3        1          RUS           3.0       5.0     256   George Russell
# 4        1          NOR           7.0       6.0     387     Lando Norris
# ..     ...          ...           ...       ...     ...              ...
# 379      2          TSU           9.0      16.0      29     Yuki Tsunoda
# 380      2          ALO          13.0      17.0      70  Fernando Alonso
# 381      2          LEC           6.0      18.0     331  Charles Leclerc
# 382      2          HAM           5.0      19.0     208   Lewis Hamilton
# 383      2          GAS          16.0      20.0      40     Pierre Gasly
#
#            TeamId  AvgQualiPosition  AvgRacePosition  QualifyingScore
# 0        red_bull          3.538462         3.576923         2.269231
# 1        williams          6.240000         6.360000         5.120000
# 2         ferrari          5.500000         5.192308         3.750000
# 3        mercedes          5.423077         6.461538         4.211538
# 4         mclaren          3.269231         4.076923         5.134615
# ..            ...               ...              ...              ...
# 379            rb         10.769231        13.230769         9.884615
# 380  aston_martin          9.653846        10.692308        11.326923
# 381       ferrari          5.500000         5.192308         5.750000
# 382       ferrari          8.653846         7.538462         6.826923
# 383        alpine         13.076923        13.076923        14.538462
#
# [384 rows x 10 columns]

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384 entries, 0 to 383
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Round             384 non-null    int64
#  1   Abbreviation      384 non-null    object
#  2   GridPosition      384 non-null    float64
#  3   Position          384 non-null    float64
#  4   Points            384 non-null    int32
#  5   DriverName        384 non-null    object
#  6   TeamId            384 non-null    object
#  7   AvgQualiPosition  384 non-null    float64
#  8   AvgRacePosition   384 non-null    float64
#  9   QualifyingScore   384 non-null    float64
# dtypes: float64(5), int32(1), int64(1), object(3)
# memory usage: 28.6+ KB

# %%
# Count and find if there are any null values in the dataset
final_df.isnull().sum()
# Out:
# Round               0
# Abbreviation        0
# GridPosition        0
# Position            0
# Points              0
# DriverName          0
# TeamId              0
# AvgQualiPosition    0
# AvgRacePosition     0
# QualifyingScore     0
# dtype: int64

# %%
final_df.to_csv('model/DATA/f1_final_data.csv', index=False)
